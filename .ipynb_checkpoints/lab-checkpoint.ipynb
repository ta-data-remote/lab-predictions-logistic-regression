# %% [markdown]
# Instructions
# Create a query or queries to extract the information you think may be relevant for building the prediction model. It should include some film features and some rental features (X).
# Create a query to get the list of all unique film titles and a boolean indicating if it was rented (rental_date) in May 2005. (Create new column called - 'rented_in_may'). This will be our TARGET (y) variable.
# Read the data into a Pandas dataframe. At this point you should have 1000 rows. Number of columns depends on the number of features you chose.
# Analyze extracted features (X) and transform them. You may need to encode some categorical variables, or scale numerical variables.
# Create a logistic regression model to predict 'rented_in_may' from the cleaned data.
# Evaluate the results.

# %%
import pandas as pd
import numpy as np
import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication
from getpass import getpass           # To get the password without showing the input
import matplotlib.pyplot as plt
import seaborn as sns

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)
engine.connect()

# %%
query = '''SELECT f.title as film_title,
                f.film_id,
                  f.rental_duration,
                  f.rental_rate,
                  f.rating,
                  f.length,
                  f.replacement_cost,
                  COUNT(DISTINCT r.rental_id) AS rental_count,
                  COUNT(DISTINCT i.inventory_id) AS inventory_count,
                  COUNT(DISTINCT fa.actor_id) AS actor_count,
                  CASE 
                      WHEN f.title IN
                          (SELECT DISTINCT f.title as film_title
                           FROM film f
                           JOIN inventory i USING (film_id)
                           JOIN rental USING (inventory_id)
                           WHERE rental.rental_date LIKE "2005-05%%")
                      THEN "1"
                      ELSE "0"
                  END AS rented_in_may
          FROM film f
             JOIN inventory i USING (film_id)
             JOIN rental r USING (inventory_id)
             JOIN film_category fc USING (film_id)
             JOIN film_actor fa USING (film_id)
          GROUP BY f.film_id;'''

film = pd.read_sql_query(query, engine)
film
# Out:
#             film_title  film_id  rental_duration  rental_rate rating  length  \
# 0     ACADEMY DINOSAUR        1                6         0.99     PG      86
# 1       ACE GOLDFINGER        2                3         4.99      G      48
# 2     ADAPTATION HOLES        3                7         2.99  NC-17      50
# 3     AFFAIR PREJUDICE        4                5         2.99      G     117
# 4          AFRICAN EGG        5                6         2.99      G     130
# ..                 ...      ...              ...          ...    ...     ...
# 950     YOUNG LANGUAGE      996                6         0.99      G     183
# 951         YOUTH KICK      997                4         0.99  NC-17     179
# 952       ZHIVAGO CORE      998                6         0.99  NC-17     105
# 953  ZOOLANDER FICTION      999                5         2.99      R     101
# 954          ZORRO ARK     1000                3         4.99  NC-17      50
#
#      replacement_cost  rental_count  inventory_count  actor_count  \
# 0               20.99            23                7           10
# 1               12.99             7                3            4
# 2               18.99            12                4            5
# 3               26.99            23                7            5
# 4               22.99            12                3            5
# ..                ...           ...              ...          ...
# 950              9.99             7                2            5
# 951             14.99             6                2            5
# 952             10.99             9                2            6
# 953             28.99            17                5            5
# 954             18.99            31                8            3
#
#     rented_in_may
# 0               1
# 1               0
# 2               1
# 3               1
# 4               1
# ..            ...
# 950             0
# 951             0
# 952             1
# 953             1
# 954             1
#
# [955 rows x 11 columns]

# %%
query1 = 'SELECT film_category.film_id, category.name AS category_name FROM sakila.film_category JOIN sakila.category USING (category_id)'
film_category = pd.read_sql_query(query1, engine)
film_category

film = pd.merge(left=film,right=film_category,how = 'inner',left_on = 'film_id', right_on='film_id')

film = film.drop("film_id", axis=1)
film
# Out:
#             film_title  rental_duration  rental_rate rating  length  \
# 0     ACADEMY DINOSAUR                6         0.99     PG      86
# 1       ACE GOLDFINGER                3         4.99      G      48
# 2     ADAPTATION HOLES                7         2.99  NC-17      50
# 3     AFFAIR PREJUDICE                5         2.99      G     117
# 4          AFRICAN EGG                6         2.99      G     130
# ..                 ...              ...          ...    ...     ...
# 950     YOUNG LANGUAGE                6         0.99      G     183
# 951         YOUTH KICK                4         0.99  NC-17     179
# 952       ZHIVAGO CORE                6         0.99  NC-17     105
# 953  ZOOLANDER FICTION                5         2.99      R     101
# 954          ZORRO ARK                3         4.99  NC-17      50
#
#      replacement_cost  rental_count  inventory_count  actor_count  \
# 0               20.99            23                7           10
# 1               12.99             7                3            4
# 2               18.99            12                4            5
# 3               26.99            23                7            5
# 4               22.99            12                3            5
# ..                ...           ...              ...          ...
# 950              9.99             7                2            5
# 951             14.99             6                2            5
# 952             10.99             9                2            6
# 953             28.99            17                5            5
# 954             18.99            31                8            3
#
#     rented_in_may category_name
# 0               1   Documentary
# 1               0        Horror
# 2               1   Documentary
# 3               1        Horror
# 4               1        Family
# ..            ...           ...
# 950             0   Documentary
# 951             0         Music
# 952             1        Horror
# 953             1      Children
# 954             1        Comedy
#
# [955 rows x 11 columns]

# %%
film.isna().sum().sum()
# Out:
# 0

# %%
numerical_columns= film.select_dtypes(include=[np.number]) 
numerical_columns.describe()
# Out:
#        rental_duration  rental_rate      length  replacement_cost  \
# count       955.000000    955.00000  955.000000        955.000000
# mean          4.967539      2.97534  115.363351         20.051780
# std           1.405289      1.64189   40.430401          6.058014
# min           3.000000      0.99000   46.000000          9.990000
# 25%           4.000000      0.99000   80.000000         14.990000
# 50%           5.000000      2.99000  114.000000         19.990000
# 75%           6.000000      4.99000  149.500000         24.990000
# max           7.000000      4.99000  185.000000         29.990000
#
#        rental_count  inventory_count  actor_count
# count    955.000000       955.000000   955.000000
# mean      16.758115         4.782199     5.493194
# std        6.682303         1.816157     2.312736
# min        4.000000         2.000000     1.000000
# 25%       11.000000         3.000000     4.000000
# 50%       16.000000         5.000000     5.000000
# 75%       22.000000         6.000000     7.000000
# max       34.000000         8.000000    15.000000

# %%
categorical_columns = film.select_dtypes(include='object') #Solo columnas objeto
categorical_columns.describe()
# Out:
#               film_title rating rented_in_may category_name
# count                955    955           955           955
# unique               955      5             2            16
# top     ACADEMY DINOSAUR  PG-13             1        Sports
# freq                   1    213           684            72

# %%
correlations_matrix = numerical_columns.corr()
sns.heatmap(correlations_matrix, annot=True)  #Mapa de calor de correlaciones
plt.show()

# %%
sns.displot(film['rental_duration'], kde=True)
plt.tight_layout()  
plt.show()

sns.displot(film['rental_rate'], kde=True)
plt.tight_layout()  
plt.show()

sns.displot(film['length'], kde=True)
plt.tight_layout()  
plt.show()

sns.displot(film['replacement_cost'], kde=True)
plt.tight_layout()  
plt.show()

sns.displot(film['rental_count'], kde=True)
plt.tight_layout()  
plt.show()

sns.displot(film['inventory_count'], kde=True)
plt.tight_layout()  
plt.show()

sns.displot(film['actor_count'], kde=True)
plt.tight_layout()  
plt.show()

# %%
film = film.drop("film_title" , axis=1)
film
# Out:
#      rental_duration  rental_rate rating  length  replacement_cost  \
# 0                  6         0.99     PG      86             20.99
# 1                  3         4.99      G      48             12.99
# 2                  7         2.99  NC-17      50             18.99
# 3                  5         2.99      G     117             26.99
# 4                  6         2.99      G     130             22.99
# ..               ...          ...    ...     ...               ...
# 950                6         0.99      G     183              9.99
# 951                4         0.99  NC-17     179             14.99
# 952                6         0.99  NC-17     105             10.99
# 953                5         2.99      R     101             28.99
# 954                3         4.99  NC-17      50             18.99
#
#      rental_count  inventory_count  actor_count rented_in_may category_name
# 0              23                7           10             1   Documentary
# 1               7                3            4             0        Horror
# 2              12                4            5             1   Documentary
# 3              23                7            5             1        Horror
# 4              12                3            5             1        Family
# ..            ...              ...          ...           ...           ...
# 950             7                2            5             0   Documentary
# 951             6                2            5             0         Music
# 952             9                2            6             1        Horror
# 953            17                5            5             1      Children
# 954            31                8            3             1        Comedy
#
# [955 rows x 10 columns]

# %%
y = film['rented_in_may']
X = film.drop('rented_in_may', axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=400)

# %%
X_train_num = X_train.select_dtypes(include=[np.number])  

# Scaling data
transformer = MinMaxScaler().fit(X_train_num) # need to keep transformer
X_train_normalized = transformer.transform(X_train_num)
X_train_norm = pd.DataFrame(X_train_normalized, columns=numerical_columns.columns)
X_train_norm
# Out:
#      rental_duration  rental_rate    length  replacement_cost  rental_count  \
# 0               0.25          1.0  0.071942              0.55      0.400000
# 1               0.75          1.0  0.215827              0.20      0.066667
# 2               0.75          0.0  0.187050              0.55      0.133333
# 3               0.25          0.5  0.007194              0.65      0.866667
# 4               0.75          0.0  0.417266              0.65      0.266667
# ..               ...          ...       ...               ...           ...
# 759             0.25          0.5  0.352518              0.70      0.666667
# 760             0.50          1.0  0.697842              0.85      0.300000
# 761             0.75          1.0  0.985612              0.25      0.066667
# 762             0.25          0.0  0.057554              0.25      0.933333
# 763             0.50          1.0  0.597122              0.40      0.133333
#
#      inventory_count  actor_count
# 0           0.500000     0.428571
# 1           0.000000     0.285714
# 2           0.000000     0.357143
# 3           0.833333     0.500000
# 4           0.333333     0.642857
# ..               ...          ...
# 759         0.666667     0.500000
# 760         0.333333     0.214286
# 761         0.000000     0.357143
# 762         1.000000     0.571429
# 763         0.166667     0.142857
#
# [764 rows x 7 columns]

# %%
X_train_categorical = X_train.select_dtypes(include = object)
X_train_cat = pd.get_dummies(X_train_categorical, 
                             columns=['rating', 'category_name'],
                             drop_first=True)
X_train_cat.head()
# Out:
#      rating_NC-17  rating_PG  rating_PG-13  rating_R  category_name_Animation  \
# 209             0          0             0         0                        0
# 380             1          0             0         0                        0
# 538             0          0             0         1                        0
# 829             0          1             0         0                        0
# 181             0          1             0         0                        0
#
#      category_name_Children  category_name_Classics  category_name_Comedy  \
# 209                       0                       0                     0
# 380                       0                       0                     0
# 538                       0                       0                     0
# 829                       0                       0                     0
# 181                       0                       0                     0
#
#      category_name_Documentary  category_name_Drama  category_name_Family  \
# 209                          0                    0                     0
# 380                          0                    0                     0
# 538                          0                    0                     0
# 829                          0                    0                     0
# 181                          0                    0                     0
#
#      category_name_Foreign  category_name_Games  category_name_Horror  \
# 209                      0                    0                     0
# 380                      0                    0                     0
# 538                      1                    0                     0
# 829                      0                    0                     0
# 181                      0                    0                     0
#
#      category_name_Music  category_name_New  category_name_Sci-Fi  \
# 209                    0                  1                     0
# 380                    0                  0                     0
# 538                    0                  0                     0
# 829                    0                  0                     0
# 181                    0                  0                     0
#
#      category_name_Sports  category_name_Travel
# 209                     0                     0
# 380                     0                     1
# 538                     0                     0
# 829                     0                     0
# 181                     0                     0

# %%
X_train_transformed = np.concatenate([X_train_norm, X_train_cat], axis=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classification = LogisticRegression(random_state=0,
                  multi_class='multinomial').fit(X_train_transformed, y_train)

# %%
# for numericals
X_test_num = X_test.select_dtypes(include = np.number)

# Scaling data
# we use the transformer that was trained on the training data
X_test_normalized = transformer.transform(X_test_num)
X_test_norm = pd.DataFrame(X_test_normalized)
X_test_norm.head()
# Out:
#       0    1         2     3         4         5         6
# 0  0.25  0.0  0.697842  0.35  0.766667  0.833333  0.142857
# 1  0.25  0.5  0.086331  0.65  0.433333  0.666667  0.142857
# 2  0.75  0.5  0.553957  0.85  0.433333  0.333333  0.714286
# 3  0.75  0.5  0.870504  0.40  0.300000  0.500000  0.285714
# 4  1.00  0.5  0.805755  0.35  0.466667  0.500000  0.571429

# %%
# for categoricals
X_test_categorical = X_test.select_dtypes(include = object)
X_test_cat = pd.get_dummies(X_test_categorical, 
                            columns=['rating', 'category_name'],
                            drop_first=True)

# %%
X_test_cat.head()
# Out:
#      rating_NC-17  rating_PG  rating_PG-13  rating_R  category_name_Animation  \
# 211             0          0             1         0                        0
# 455             0          1             0         0                        0
# 533             1          0             0         0                        0
# 275             0          0             0         0                        0
# 268             1          0             0         0                        0
#
#      category_name_Children  category_name_Classics  category_name_Comedy  \
# 211                       0                       1                     0
# 455                       0                       0                     0
# 533                       0                       0                     0
# 275                       0                       0                     0
# 268                       0                       0                     0
#
#      category_name_Documentary  category_name_Drama  category_name_Family  \
# 211                          0                    0                     0
# 455                          0                    0                     0
# 533                          0                    0                     0
# 275                          0                    0                     0
# 268                          0                    0                     0
#
#      category_name_Foreign  category_name_Games  category_name_Horror  \
# 211                      0                    0                     0
# 455                      0                    0                     0
# 533                      0                    0                     0
# 275                      0                    0                     0
# 268                      0                    0                     0
#
#      category_name_Music  category_name_New  category_name_Sci-Fi  \
# 211                    0                  0                     0
# 455                    0                  1                     0
# 533                    0                  1                     0
# 275                    0                  0                     0
# 268                    0                  0                     0
#
#      category_name_Sports  category_name_Travel
# 211                     0                     0
# 455                     0                     0
# 533                     0                     0
# 275                     1                     0
# 268                     0                     1

# %%
X_train_cat.columns
# Out:
# Index(['rating_NC-17', 'rating_PG', 'rating_PG-13', 'rating_R',
#        'category_name_Animation', 'category_name_Children',
#        'category_name_Classics', 'category_name_Comedy',
#        'category_name_Documentary', 'category_name_Drama',
#        'category_name_Family', 'category_name_Foreign', 'category_name_Games',
#        'category_name_Horror', 'category_name_Music', 'category_name_New',
#        'category_name_Sci-Fi', 'category_name_Sports', 'category_name_Travel'],
#       dtype='object')

# %%
X_test_cat.columns
# Out:
# Index(['rating_NC-17', 'rating_PG', 'rating_PG-13', 'rating_R',
#        'category_name_Animation', 'category_name_Children',
#        'category_name_Classics', 'category_name_Comedy',
#        'category_name_Documentary', 'category_name_Drama',
#        'category_name_Family', 'category_name_Foreign', 'category_name_Games',
#        'category_name_Horror', 'category_name_Music', 'category_name_New',
#        'category_name_Sci-Fi', 'category_name_Sports', 'category_name_Travel'],
#       dtype='object')

# %%
list(zip(list(X_train_cat.columns),list(X_test_cat.columns)))
# Out:
# [('rating_NC-17', 'rating_NC-17'),
#  ('rating_PG', 'rating_PG'),
#  ('rating_PG-13', 'rating_PG-13'),
#  ('rating_R', 'rating_R'),
#  ('category_name_Animation', 'category_name_Animation'),
#  ('category_name_Children', 'category_name_Children'),
#  ('category_name_Classics', 'category_name_Classics'),
#  ('category_name_Comedy', 'category_name_Comedy'),
#  ('category_name_Documentary', 'category_name_Documentary'),
#  ('category_name_Drama', 'category_name_Drama'),
#  ('category_name_Family', 'category_name_Family'),
#  ('category_name_Foreign', 'category_name_Foreign'),
#  ('category_name_Games', 'category_name_Games'),
#  ('category_name_Horror', 'category_name_Horror'),
#  ('category_name_Music', 'category_name_Music'),
#  ('category_name_New', 'category_name_New'),
#  ('category_name_Sci-Fi', 'category_name_Sci-Fi'),
#  ('category_name_Sports', 'category_name_Sports'),
#  ('category_name_Travel', 'category_name_Travel')]

# %%
list(X_train_cat.columns)==list(X_test_cat.columns)
# Out:
# True

# %%
X_test_transformed = np.concatenate([X_test_norm, X_test_cat], axis=1)

# %%
predictions = classification.predict(X_test_transformed)
predictions
classification.score(X_test_transformed, y_test)
# Out:
# 0.8010471204188482

# %%
print(y_test.value_counts())
# Out:
# 1    139
# 0     52
# Name: rented_in_may, dtype: int64

# %%
pd.Series(predictions).value_counts()
# Out:
# 1    159
# 0     32
# dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[ 23,  29],
#        [  9, 130]])

# %%
from sklearn import neighbors
clf = neighbors.KNeighborsClassifier(n_neighbors=3, weights='uniform')
clf.fit(X_train_transformed, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
predictions_clf = clf.predict(X_test_transformed)
clf.score(X_test_transformed, y_test)
# Out:
# 0.6858638743455497

# %%
confusion_matrix(y_test, predictions_clf)
# Out:
# array([[ 15,  37],
#        [ 23, 116]])

# %%
pd.Series(y_test).value_counts()
# Out:
# 1    139
# 0     52
# Name: rented_in_may, dtype: int64

# %%
pd.Series(predictions_clf).value_counts()
# Out:
# 1    153
# 0     38
# dtype: int64

# %%
film.head()
# Out:
#    rental_duration  rental_rate rating  length  replacement_cost  \
# 0                6         0.99     PG      86             20.99
# 1                3         4.99      G      48             12.99
# 2                7         2.99  NC-17      50             18.99
# 3                5         2.99      G     117             26.99
# 4                6         2.99      G     130             22.99
#
#    rental_count  inventory_count  actor_count rented_in_may category_name
# 0            23                7           10             1   Documentary
# 1             7                3            4             0        Horror
# 2            12                4            5             1   Documentary
# 3            23                7            5             1        Horror
# 4            12                3            5             1        Family
